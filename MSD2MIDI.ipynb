# %% [markdown]
# **Load Dependencies**

# %%
# !pip install pretty_midi
# !pip install librosa
# !pip install mir_eval
# !pip install tables

# %%
# !wget http://hog.ee.columbia.edu/craffel/lmd/match_scores.json

# %%
# !wget http://hog.ee.columbia.edu/craffel/lmd/lmd_aligned.tar.gz

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pretty_midi
import librosa
import mir_eval
import mir_eval.display
import tables
import IPython.display
import os
import json

# Local path constants
DATA_PATH = 'data'
RESULTS_PATH = ''
# Path to the file match_scores.json distributed with the LMD
SCORE_FILE = os.path.join(RESULTS_PATH, 'match_scores.json')

# Utility functions for retrieving paths
def msd_id_to_dirs(msd_id):
    """Given an MSD ID, generate the path prefix.
    E.g. TRABCD12345678 -> A/B/C/TRABCD12345678"""
    return os.path.join(msd_id[2], msd_id[3], msd_id[4], msd_id)

def msd_id_to_mp3(msd_id):
    """Given an MSD ID, return the path to the corresponding mp3"""
    return os.path.join(DATA_PATH, 'msd', 'mp3',
                        msd_id_to_dirs(msd_id) + '.mp3')

def msd_id_to_h5(h5):
    """Given an MSD ID, return the path to the corresponding h5"""
    return os.path.join(RESULTS_PATH, 'lmd_matched_h5',
                        msd_id_to_dirs(msd_id) + '.h5')

def get_midi_path(msd_id, midi_md5, kind):
    """Given an MSD ID and MIDI MD5, return path to a MIDI file.
    kind should be one of 'matched' or 'aligned'. """
    return os.path.join(RESULTS_PATH, 'lmd_{}'.format(kind),
                        msd_id_to_dirs(msd_id), midi_md5 + '.mid')

# %% [markdown]
# **Match Dataset**

# %%
with open(SCORE_FILE) as f:
    scores = json.load(f)
    keys = list(scores)
# Grab a Million Song Dataset ID from the scores dictionary
msd_id = list(scores)[20]
print("Million Song Dataset ID {} has {} MIDI file matches:".format(msd_id, len(scores[msd_id])))
          
for midi_md5, score in scores[msd_id].items():
    print('  {} with confidence score {}'.format(midi_md5, score))
# Out:
# Million Song Dataset ID TREGGML12903CC0740 has 2 MIDI file matches:
#   33e3ed0356f8356f0a89a4dce5be88ad with confidence score 0.7378106284252202
#   ffca0861fd3a0d536ebdabdf9853a3fe with confidence score 0.7378074024297993

# %%
while True:
    # Grab an MSD ID and its dictionary of matches
    msd_id, matches = scores.popitem()
    # Grab a MIDI from the matches
    midi_md5, score = matches.popitem()
    # Construct the path to the aligned MIDI
    matched_midi_path = 'lmd_aligned.mid' 
    # Load/parse the MIDI file with pretty_midi
    pm = pretty_midi.PrettyMIDI(matched_midi_path)
    # Look for a MIDI file which has lyric and key signature change events
    if len(pm.lyrics) > 5 and len(pm.key_signature_changes) > 0:
        break
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-a2633a6b7f74> in <module>()
#       7     matched_midi_path = 'lmd_aligned.tar.gz'
#       8     # Load/parse the MIDI file with pretty_midi
# ----> 9     pm = pretty_midi.PrettyMIDI(matched_midi_path)
#      10     # Look for a MIDI file which has lyric and key signature change events
#      11     if len(pm.lyrics) > 5 and len(pm.key_signature_changes) > 0:
#
# /usr/local/lib/python3.6/dist-packages/pretty_midi/pretty_midi.py in __init__(self, midi_file, resolution, initial_tempo)
#      57             if isinstance(midi_file, six.string_types):
#      58                 # If a string was given, pass it as the string filename
# ---> 59                 midi_data = mido.MidiFile(filename=midi_file)
#      60             else:
#      61                 # Otherwise, try passing it in as a file pointer
#
# /usr/local/lib/python3.6/dist-packages/mido/midifiles/midifiles.py in __init__(self, filename, file, type, ticks_per_beat, charset, debug)
#     300         elif self.filename is not None:
#     301             with io.open(filename, 'rb') as file:
# --> 302                 self._load(file)
#     303
#     304     def add_track(self, name=None):
#
# /usr/local/lib/python3.6/dist-packages/mido/midifiles/midifiles.py in _load(self, infile)
#     324             (self.type,
#     325              num_tracks,
# --> 326              self.ticks_per_beat) = read_file_header(infile)
#     327
#     328             if self.debug:
#
# /usr/local/lib/python3.6/dist-packages/mido/midifiles/midifiles.py in read_file_header(infile)
#     108
#     109     if name != b'MThd':
# --> 110         raise IOError('MThd not found. Probably not a MIDI file')
#     111     else:
#     112         data = infile.read(size)
#
# OSError: MThd not found. Probably not a MIDI file
